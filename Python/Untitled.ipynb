# %%
from openpyxl import load_workbook
import pylab as pylab
import numpy as np
from matplotlib.mlab import griddata
import matplotlib.pyplot as plt

# %%
wb = load_workbook('Toma4_reducido.xlsx')
wsh = wb['suma']
x,y,canalB = wsh['A2':'A442'],wsh['B2':'B442'],wsh['H2':'H442']
X,Y,Z=[],[],[]

for i in range(len(x)):
    X.append(x[i][0].value)
    Y.append(y[i][0].value)
    Z.append(canalB[i][0].value)
    
print X[0]
# Out:
# -2

# %%
# %matplotlib inline 
# make up data.
#random_state = np.random.RandomState(19680801)

npts = 21

# define grid.
xi = np.linspace(-2, 2, 21)
yi = np.linspace(-2, 2, 21)
# grid the data.
zi = griddata(X, Y, Z, xi, yi, interp='linear')
# contour the gridded data, plotting dots at the nonuniform data points.
CS = plt.contour(xi, yi, zi, 15, linewidths=0.5, colors='k')
CS = plt.contourf(xi, yi, zi, 15,
                  vmax=abs(zi).max(), vmin=-abs(zi).max())
plt.colorbar()  # draw colorbar
# plot data points.
plt.scatter(X, Y, marker='o', s=5, zorder=10)
plt.xlim(-2, 2)
plt.ylim(-2, 2)
plt.title('griddata test (%d points)' % npts)
plt.show()

# %%
wb = load_workbook('Toma5_reducido.xlsx')
wsh = wb.get_sheet_by_name('suma')
x,y,canalB = wsh['A2':'A442'],wsh['B2':'B442'],wsh['H2':'H442']
X,Y,Z=[],[],[]

for i in range(len(x)):
    X.append(x[i][0].value)
    Y.append(y[i][0].value)
    Z.append(canalB[i][0].value)
    
print X[0]


npts = 21

# define grid.
xi = np.linspace(-2, 2, 21)
yi = np.linspace(-2, 2, 21)
# grid the data.
zi = griddata(X, Y, Z, xi, yi, interp='linear')
# contour the gridded data, plotting dots at the nonuniform data points.
CS = plt.contour(xi, yi, zi, 15, linewidths=0.5, colors='k')
CS = plt.contourf(xi, yi, zi, 15,
                  vmax=abs(zi).max(), vmin=-abs(zi).max())
plt.colorbar()  # draw colorbar
# plot data points.
plt.scatter(X, Y, marker='o', s=5, zorder=10)
plt.xlim(-2, 2)
plt.ylim(-2, 2)
plt.title('griddata test (%d points)' % npts)
plt.show()
# Out:
# -2

# %%
wb = load_workbook('Ghost_DetAV_DetCH_reducido.xlsx')
wsh = wb.get_sheet_by_name('suma')
x,y,canalB = wsh['A2':'A1682'],wsh['B2':'B1682'],wsh['I2':'I1682']
X,Y,Z=[],[],[]

for i in range(len(x)):
    X.append(x[i][0].value)
    Y.append(y[i][0].value)
    Z.append(canalB[i][0].value)
    
print X[0]


npts = 21

# define grid.
xi = np.linspace(-2, 2, 21)
yi = np.linspace(-2, 2, 21)
# grid the data.
zi = griddata(X, Y, Z, xi, yi, interp='linear')
# contour the gridded data, plotting dots at the nonuniform data points.
CS = plt.contour(xi, yi, zi, 15, linewidths=0.5, colors='k')
CS = plt.contourf(xi, yi, zi, 15,
                  vmax=abs(zi).max(), vmin=-abs(zi).max())
plt.colorbar()  # draw colorbar
# plot data points.
plt.scatter(X, Y, marker='o', s=5, zorder=10)
plt.xlim(-2, 2)
plt.ylim(-2, 2)
plt.title('griddata test (%d points)' % npts)
plt.show()
# Out:
# -2
